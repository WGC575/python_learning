# %%
#We use two-sided fisher exact test to analyze whether there is significant difference between types (29 types) of commits (by purpose) and whether they witness a increase of software metrics.

#FindBugs_1
import scipy.stats as ss
import pandas as pd
import numpy

neutral = pd.read_csv('./neutral_metric.csv',)
fb_1 = pd.read_csv('./fb_1.csv')
#print(fb_1.columns)
#print(neutral)
#print(fb_1)
#neutral.head()

for j in fb_1.columns:
    for i in neutral.columns:
        print(ss.fisher_exact([[neutral[i][0],neutral[i][1]],[fb_1[j][0], fb_1[j][1]]],"two-sided")[1])
    print("\n")
        
        #print(mat[i][0])
# Out:
# 4.950832333966e-311
# 1.6590412397819375e-114
# 6.421388119229081e-219
# 2.0437101510113595e-161
# 9.41849298209573e-287
# 6.675334566388727e-276
# 2.747321982515592e-308
# 7.059396993951019e-292
# 3.298494080676258e-120
# 4.950832333966e-311
# 1.0642006822707416e-107
# 5.3625856917655416e-250
# 2.747321982515592e-308
# 2.747321982515592e-308
# 3.802841013547073e-266
# 8.873806304654009e-05
# 2.747321982515592e-308
# 4.950832333966e-311
# 2.747321982515592e-308
# 2.747321982515592e-308
# 4.950832333966e-311
# 3.0523689093899063e-215
# 2.747321982515592e-308
# 5.058999405920927e-12
# 2.0157497585027177e-258
# 2.19302766611534e-299
# 5.6011954381052835e-15
# 5.125714196330598e-209
# 2.0157497585027177e-258
#
#
# 5.4159413229585876e-08
# 7.88476627566118e-46
# 4.621948909125315e-06
# 1.5115229733229788e-22
# 0.045753305397182795
# 0.44818210492220956
# 7.365576412422771e-07
# 0.008681990930200913
# 2.138890877341011e-42
# 5.4159413229585876e-08
# 3.4152517153966845e-50
# ...
